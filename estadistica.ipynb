# %%
import pandas as pd

# %%
data_0 = {'sexo': ['masculino','femenino','otro'], 'codigo' : [0,1,2], 'frecuencia': [5,6,2]}
pd_0 = pd.DataFrame(data=data_0)
pd_0
# Out:
#         sexo  codigo  frecuencia
# 0  masculino       0           5
# 1   femenino       1           6
# 2       otro       2           2

# %%
df = pd.read_csv("G:/My Drive/Programacion/curso de estadistica con python/archivos/nhanes_2015_2016.csv")
df.head()
# Out:
#     SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1
# 0  83732     1.0     NaN     1.0       1         1        62         3  \
# 1  83733     1.0     NaN     6.0       1         1        53         3
# 2  83734     1.0     NaN     NaN       1         1        78         3
# 3  83735     2.0     1.0     1.0       2         2        56         3
# 4  83736     2.0     1.0     1.0       2         2        42         4
#
#    DMDCITZN  DMDEDUC2  ...  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  BMXLEG
# 0       1.0       5.0  ...   124.0    64.0   94.8  184.5    27.8    43.3  \
# 1       2.0       3.0  ...   140.0    88.0   90.4  171.4    30.8    38.0
# 2       1.0       3.0  ...   132.0    44.0   83.4  170.1    28.8    35.6
# 3       1.0       5.0  ...   134.0    68.0  109.8  160.9    42.4    38.5
# 4       1.0       4.0  ...   114.0    54.0   55.2  164.9    20.3    37.4
#
#    BMXARML  BMXARMC  BMXWAIST  HIQ210
# 0     43.6     35.9     101.1     2.0
# ...

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()
dias = ["L","M","M","J","V","S","D"]
temperaturas = {'BsAs': [28,30,25,31,28,29,30], 'SantaFe': [35,38,40,36,40,41,42]}
ax.plot(dias,temperaturas['BsAs'],color='tab:purple', marker='*', label='Buenos Aires')
ax.plot(dias,temperaturas['SantaFe'], color='tab:green', marker='*', label='SantaFe')

# %%
fig_2, ax_2 = plt.subplots()
ax_2.bar(dias,temperaturas['SantaFe'],label="SantaFe",color='green')
ax_2.bar(dias,temperaturas['BsAs'],label="BuenosAires",color='purple')
plt.legend(loc='best') #lo pone en la mejor ubicacion
plt.show()

# %%
fig_3, ax_3 = plt.subplots()
sexos = data_0['sexo']
frecuencias = data_0['frecuencia']
ax_3.bar(sexos,frecuencias, color='purple')
plt.show()

# %% [markdown]
# ### si quiero sacar la media recortada

# %%
from scipy.stats import trim_mean
trim_mean(medals['total'],0.1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 from scipy.stats import trim_mean
# ----> 2 trim_mean(medals['total'],0.1)
#
# NameError: name 'medals' is not defined

# %%
import numpy as np # vectores y matrices
import pandas as pd # tablas
import matplotlib.pyplot as plt #graficar
import statistics #operaciones basica de estadistica
from scipy.stats import norm #estadistica avanzada y matematica

# %%
# en este caso estoy utilizando numpy
notasAlumnos = [1,2,3,4,5,6,7,9,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10]
promedio = np.mean(notasAlumnos)
varianza = np.var(notasAlumnos)
desviacionEstandar = np.std(notasAlumnos)
mensaje = "media es: {}, la variaza es: {} y desviacion estandar es: {}"
print(mensaje.format(promedio,varianza,desviacionEstandar))
# Out:
# media es: 8.208333333333334, la variaza es: 8.498263888888888 y desviacion estandar es: 2.915178191618634

# %%
intervalos = range(min(notasAlumnos), max(notasAlumnos)+1)
print(intervalos)
plt.hist(notasAlumnos,bins=intervalos, color='purple', rwidth=0.98)
plt.scatter(promedio,0, color="red", linewidths=5)
plt.title("histograma")
plt.xlabel("Notas")
plt.ylabel("frecuencia")
plt.xticks(intervalos)
# Out:
# range(1, 11)
# ([<matplotlib.axis.XTick at 0x20641f7bed0>,
# ...
#  [Text(1, 0, '1'),
#   Text(2, 0, '2'),
#   Text(3, 0, '3'),
#   Text(4, 0, '4'),
#   Text(5, 0, '5'),
#   Text(6, 0, '6'),
#   Text(7, 0, '7'),
#   Text(8, 0, '8'),
#   Text(9, 0, '9'),
#   Text(10, 0, '10')])

# %%
serie = [10,25,32,48,49,45,22,46,29,49,43,48,15,45,62,38,43,69,38,46,34,54,45,46,18,45,32,34,62,44,42,44,62,42,35,66,12,27,49,35,55,37,31,64,17,33,80,68,42,43,61,74,14,34,76,28,26,34,38,26]
promedio1 = np.mean(serie)
varianzaEstandar1 = np.std(serie)

plt.axvline(x=promedio1+varianzaEstandar1, color='blue', linestyle='-', label='Promedio')
plt.axvline(x=promedio1-varianzaEstandar1, color='blue', linestyle='-', label='Promedio')
plt.axvline(x=promedio1, color='blue', linestyle='-', label='Promedio')

plt.hist(serie,bins=6, color='purple')
plt.title("histograma")
plt.xlabel("cantidad")
plt.ylabel("frecuencia")

print(promedio1)
print(varianzaEstandar1)
# Out:
# 41.85
# 16.09018852178764

# %%
url = "G:/My Drive/Programacion/curso de python/medals.csv"
medals = pd.read_csv(url)
varMedals = np.var(medals['Total'])
mediaMedals = np.mean(medals['Total'])
print(mediaMedals)
print(varMedals)
print(medals)
# Out:
# 11.612903225806452
# 360.55983350676394
#                        Country  Gold Medal  Silver Medal  Bronze Medal  Total
# 0     United States of America          39            41            33    113  \
# 1   People's Republic of China          38            32            18     88
# 2                        Japan          27            14            17     58
# 3                Great Britain          22            21            22     65
# 4                          ROC          20            28            23     71
# ..                         ...         ...           ...           ...    ...
# 88                       Ghana           0             0             1      1
# 89                     Grenada           0             0             1      1
# 90                      Kuwait           0             0             1      1
# 91         Republic of Moldova           0             0             1      1
# ...

# %%
#fig_1 es una variable que representa la figura creada.
#ax_1 es una variable que representa los ejes asociados a esa figura.

fig_1, ax_1 = plt.subplots()
ax_1.bar(medals['Country'],medals['Total'],color='skyblue')
#la linea horizontal es la media
ax_1.axhline(y = mediaMedals, color='red', linestyle="-")

# %%
A = {1,2,3,3,5,6,7,9}

# %%
data_example = pd.DataFrame([1,2,3,3,5,6,7,9])
print("media:",data_example.mean())  #utilizo pandas
print("desvio estandar:", data_example.std())

# percentiles con numpy
# el 75% esta por debajo de 6.25
print("Q3:", np.percentile(data_example,[75]))
print("q3 - q1: ", np.percentile(data_example,[75,25]))
#es una medida mucho mas fiable que la media en datos muy grandes
print("rango intercuartil: ",6.75-2.75)
print(data_example.describe())


data_example.plot(kind='box')
# Out:
# media: 0    4.5
# dtype: float64
# desvio estandar: 0    2.725541
# dtype: float64
# Q3: [6.25]
# q3 - q1:  [6.25 2.75]
# rango intercuartil:  4.0
#               0
# count  8.000000
# mean   4.500000
# std    2.725541
# min    1.000000
# 25%    2.750000
# 50%    4.000000
# 75%    6.250000
# max    9.000000
# <Axes: >

# %%
from scipy.stats import norm
x_norm = np.arange(-3,3,0.001) #intervalo
plt.plot(x_norm,norm.pdf(x_norm,0,1))

plt.axvline(x=0,color='red', linestyle='-')
